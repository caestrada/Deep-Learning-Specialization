# %% [markdown]
# # Logistic Regression

# %%
import torch
from fastai.vision.all import *
from utils import load_dataset
# import copy

# %% [markdown]
# ## Dataset

# %%
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y = load_dataset()
print(train_set_x_orig.shape)
print(train_set_y.shape)
print(test_set_x_orig.shape)
print(test_set_y.shape)
# Out:
# torch.Size([209, 64, 64, 3])
# torch.Size([1, 209])
# torch.Size([50, 64, 64, 3])
# torch.Size([1, 50])

# %%
img_t = train_set_x_orig[25]
show_image(img_t)
img_t.shape
# Out:
# torch.Size([64, 64, 3])

# %%
# Process each channel separately
channels = ['Reds', 'Greens', 'Blues']
for i, color in enumerate(channels):
    # Extract one color channel
    channel_data = img_t[0:20,0:20, i]

    # Convert to DataFrame
    df = pd.DataFrame(channel_data)

    # You can apply styling and display each channel
    display(df.style.set_properties(**{'font-size':'4pt'}).background_gradient(color, axis=None))
# Out:
# <style type="text/css">
# #T_d8681_row0_col0, #T_d8681_row0_col6, #T_d8681_row1_col3, #T_d8681_row3_col0, #T_d8681_row3_col4, #T_d8681_row5_col7, #T_d8681_row6_col3, #T_d8681_row6_col17, #T_d8681_row7_col3, #T_d8681_row8_col3, #T_d8681_row10_col2, #T_d8681_row14_col4, #T_d8681_row14_col6, #T_d8681_row15_col5, #T_d8681_row15_col6, #T_d8681_row19_col11 {
#   font-size: 4pt;
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_d8681_row0_col1, #T_d8681_row0_col2, #T_d8681_row3_col15, #T_d8681_row5_col3, #T_d8681_row7_col2, #T_d8681_row8_col2, #T_d8681_row11_col3, #T_d8681_row14_col3, #T_d8681_row15_col8 {
#   font-size: 4pt;
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_d8681_row0_col3, #T_d8681_row1_col19, #T_d8681_row10_col4, #T_d8681_row11_col4, #T_d8681_row13_col7, #T_d8681_row16_col5, #T_d8681_row16_col6 {
#   font-size: 4pt;
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_d8681_row0_col4, #T_d8681_row2_col5, #T_d8681_row4_col5, #T_d8681_row6_col4, #T_d8681_row7_col4, #T_d8681_row8_col7, #T_d8681_row9_col7, #T_d8681_row10_col1, #T_d8681_row10_col5, #T_d8681_row12_col6, #T_d8681_row16_col2, #T_d8681_row17_col5, #T_d8681_row17_col6, #T_d8681_row17_col7, #T_d8681_row17_col8 {
#   font-size: 4pt;
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_d8681_row0_col5, #T_d8681_row3_col6, #T_d8681_row4_col6, #T_d8681_row11_col6, #T_d8681_row11_col7, #T_d8681_row16_col1, #T_d8681_row17_col3, #T_d8681_row17_col10 {
#   font-size: 4pt;
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_d8681_row0_col7, #T_d8681_row7_col19, #T_d8681_row11_col18 {
#   font-size: 4pt;
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_d8681_row0_col8, #T_d8681_row13_col18, #T_d8681_row14_col19 {
#   font-size: 4pt;
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_d8681_row0_col9, #T_d8681_row0_col14 {
#   font-size: 4pt;
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_d8681_row0_col10 {
#   font-size: 4pt;
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_d8681_row0_col11, #T_d8681_row1_col14 {
#   font-size: 4pt;
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_d8681_row0_col12, #T_d8681_row1_col1, #T_d8681_row2_col1, #T_d8681_row3_col1, #T_d8681_row4_col16, #T_d8681_row5_col17, #T_d8681_row6_col2, #T_d8681_row11_col9, #T_d8681_row12_col3, #T_d8681_row13_col3, #T_d8681_row15_col9, #T_d8681_row15_col10 {
#   font-size: 4pt;
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_d8681_row0_col13, #T_d8681_row2_col2, #T_d8681_row3_col2, #T_d8681_row3_col3, #T_d8681_row5_col16, #T_d8681_row14_col9 {
#   font-size: 4pt;
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_d8681_row0_col15, #T_d8681_row1_col4, #T_d8681_row7_col1, #T_d8681_row8_col1, #T_d8681_row9_col4, #T_d8681_row9_col8, #T_d8681_row13_col5, #T_d8681_row13_col6, #T_d8681_row15_col2, #T_d8681_row16_col4 {
#   font-size: 4pt;
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_d8681_row0_col16, #T_d8681_row0_col17, #T_d8681_row1_col17, #T_d8681_row1_col18, #T_d8681_row10_col0, #T_d8681_row14_col0, #T_d8681_row15_col0, #T_d8681_row17_col0, #T_d8681_row19_col0 {
#   font-size: 4pt;
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d8681_row0_col18, #T_d8681_row2_col18, #T_d8681_row8_col0, #T_d8681_row9_col0, #T_d8681_row16_col0, #T_d8681_row18_col1, #T_d8681_row18_col3, #T_d8681_row18_col4, #T_d8681_row18_col9, #T_d8681_row19_col1, #T_d8681_row19_col3, #T_d8681_row19_col4, #T_d8681_row19_col5, #T_d8681_row19_col9 {
#   font-size: 4pt;
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_d8681_row0_col19, #T_d8681_row6_col1, #T_d8681_row6_col7, #T_d8681_row12_col4, #T_d8681_row16_col7, #T_d8681_row16_col8, #T_d8681_row16_col9, #T_d8681_row16_col10 {
#   font-size: 4pt;
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_d8681_row1_col0, #T_d8681_row1_col15, #T_d8681_row2_col0, #T_d8681_row3_col18, #T_d8681_row4_col1, #T_d8681_row9_col2, #T_d8681_row9_col3, #T_d8681_row10_col3, #T_d8681_row13_col9, #T_d8681_row14_col7, #T_d8681_row15_col7 {
#   font-size: 4pt;
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_d8681_row1_col2, #T_d8681_row2_col3, #T_d8681_row2_col14, #T_d8681_row4_col3, #T_d8681_row5_col2, #T_d8681_row14_col8 {
#   font-size: 4pt;
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_d8681_row1_col5, #T_d8681_row2_col6, #T_d8681_row5_col5, #T_d8681_row5_col6, #T_d8681_row6_col0, #T_d8681_row6_col6, #T_d8681_row7_col6, #T_d8681_row8_col5, #T_d8681_row10_col6, #T_d8681_row10_col7, #T_d8681_row10_col8, #T_d8681_row11_col1, #T_d8681_row11_col5, #T_d8681_row11_col8, #T_d8681_row12_col1, #T_d8681_row12_col5, #T_d8681_row13_col1, #T_d8681_row14_col1, #T_d8681_row15_col1, #T_d8681_row17_col4, #T_d8681_row17_col9 {
#   font-size: 4pt;
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_d8681_row1_col6, #T_d8681_row5_col0, #T_d8681_row5_col4, #T_d8681_row9_col1, #T_d8681_row12_col8, #T_d8681_row16_col3 {
#   font-size: 4pt;
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d8681_row1_col7, #T_d8681_row1_col10, #T_d8681_row18_col11 {
#   font-size: 4pt;
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_d8681_row1_col8, #T_d8681_row15_col19, #T_d8681_row18_col19 {
#   font-size: 4pt;
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_d8681_row1_col9, #T_d8681_row7_col14, #T_d8681_row18_col17, #T_d8681_row18_col18 {
#   font-size: 4pt;
#   background-color: #fca689;
#   color: #000000;
# }
# #T_d8681_row1_col11, #T_d8681_row2_col13, #T_d8681_row3_col14, #T_d8681_row8_col19, #T_d8681_row10_col19 {
#   font-size: 4pt;
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_d8681_row1_col12, #T_d8681_row1_col13, #T_d8681_row7_col17, #T_d8681_row9_col19 {
#   font-size: 4pt;
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_d8681_row1_col16, #T_d8681_row2_col17, #T_d8681_row6_col5, #T_d8681_row7_col0, #T_d8681_row7_col5, #T_d8681_row17_col1, #T_d8681_row17_col2, #T_d8681_row18_col2, #T_d8681_row18_col5, #T_d8681_row18_col6, #T_d8681_row18_col7, #T_d8681_row18_col8, #T_d8681_row19_col2, #T_d8681_row19_col6, #T_d8681_row19_col7, #T_d8681_row19_col8 {
#   font-size: 4pt;
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_d8681_row2_col4, #T_d8681_row2_col19, #T_d8681_row4_col0, #T_d8681_row4_col4, #T_d8681_row12_col9, #T_d8681_row13_col2, #T_d8681_row14_col2, #T_d8681_row15_col3 {
#   font-size: 4pt;
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_d8681_row2_col7, #T_d8681_row3_col13, #T_d8681_row10_col18, #T_d8681_row12_col18 {
#   font-size: 4pt;
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_d8681_row2_col8, #T_d8681_row12_col14, #T_d8681_row13_col16 {
#   font-size: 4pt;
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col9, #T_d8681_row11_col12 {
#   font-size: 4pt;
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col10, #T_d8681_row15_col11, #T_d8681_row17_col11 {
#   font-size: 4pt;
#   background-color: #fca082;
#   color: #000000;
# }
# #T_d8681_row2_col11 {
#   font-size: 4pt;
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_d8681_row2_col12, #T_d8681_row12_col19 {
#   font-size: 4pt;
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_d8681_row2_col15, #T_d8681_row3_col19, #T_d8681_row4_col2, #T_d8681_row7_col18, #T_d8681_row8_col18 {
#   font-size: 4pt;
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_d8681_row2_col16, #T_d8681_row3_col17, #T_d8681_row4_col7, #T_d8681_row8_col8 {
#   font-size: 4pt;
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_d8681_row3_col5, #T_d8681_row7_col7, #T_d8681_row8_col4, #T_d8681_row8_col6, #T_d8681_row9_col5, #T_d8681_row9_col6, #T_d8681_row12_col7 {
#   font-size: 4pt;
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_d8681_row3_col7 {
#   font-size: 4pt;
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_d8681_row3_col8, #T_d8681_row9_col14, #T_d8681_row11_col14, #T_d8681_row16_col18 {
#   font-size: 4pt;
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col9, #T_d8681_row11_col11 {
#   font-size: 4pt;
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col10, #T_d8681_row4_col8, #T_d8681_row10_col11, #T_d8681_row10_col15, #T_d8681_row17_col19 {
#   font-size: 4pt;
#   background-
# <style type="text/css">
# #T_34408_row0_col0, #T_34408_row2_col3, #T_34408_row3_col0, #T_34408_row5_col1, #T_34408_row6_col3, #T_34408_row6_col17, #T_34408_row7_col3, #T_34408_row9_col7, #T_34408_row9_col8, #T_34408_row10_col4, #T_34408_row10_col5, #T_34408_row11_col4, #T_34408_row12_col9, #T_34408_row14_col2, #T_34408_row15_col4 {
#   font-size: 4pt;
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_34408_row0_col1, #T_34408_row0_col2, #T_34408_row0_col12, #T_34408_row0_col19, #T_34408_row1_col0, #T_34408_row1_col1, #T_34408_row1_col19, #T_34408_row2_col0, #T_34408_row2_col1, #T_34408_row2_col14, #T_34408_row2_col17, #T_34408_row3_col1, #T_34408_row3_col3, #T_34408_row3_col15, #T_34408_row4_col1, #T_34408_row4_col3, #T_34408_row5_col3, #T_34408_row8_col3, #T_34408_row9_col2, #T_34408_row9_col3, #T_34408_row9_col6, #T_34408_row10_col2, #T_34408_row10_col6, #T_34408_row11_col2, #T_34408_row12_col2, #T_34408_row13_col2, #T_34408_row13_col4, #T_34408_row13_col8, #T_34408_row14_col5, #T_34408_row14_col6, #T_34408_row15_col5, #T_34408_row15_col6, #T_34408_row15_col7, #T_34408_row19_col11 {
#   font-size: 4pt;
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_34408_row0_col3, #T_34408_row1_col18, #T_34408_row3_col4, #T_34408_row7_col1, #T_34408_row10_col8, #T_34408_row11_col8, #T_34408_row16_col4 {
#   font-size: 4pt;
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_34408_row0_col4, #T_34408_row1_col5, #T_34408_row5_col5, #T_34408_row6_col0, #T_34408_row7_col4, #T_34408_row17_col4, #T_34408_row17_col9 {
#   font-size: 4pt;
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_34408_row0_col5, #T_34408_row6_col5, #T_34408_row16_col1 {
#   font-size: 4pt;
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_34408_row0_col6, #T_34408_row1_col2, #T_34408_row1_col12, #T_34408_row1_col13, #T_34408_row1_col16, #T_34408_row2_col2, #T_34408_row2_col19, #T_34408_row3_col2, #T_34408_row4_col2, #T_34408_row4_col16, #T_34408_row5_col2, #T_34408_row5_col16, #T_34408_row5_col17, #T_34408_row6_col2, #T_34408_row6_col7, #T_34408_row7_col2, #T_34408_row7_col18, #T_34408_row8_col2, #T_34408_row8_col18, #T_34408_row10_col3, #T_34408_row11_col3, #T_34408_row12_col3, #T_34408_row13_col9, #T_34408_row14_col3, #T_34408_row14_col4, #T_34408_row14_col7, #T_34408_row15_col8, #T_34408_row15_col9, #T_34408_row15_col10 {
#   font-size: 4pt;
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_34408_row0_col7, #T_34408_row3_col17, #T_34408_row11_col19 {
#   font-size: 4pt;
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_34408_row0_col8, #T_34408_row7_col15 {
#   font-size: 4pt;
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_34408_row0_col9, #T_34408_row2_col11, #T_34408_row3_col12, #T_34408_row4_col13, #T_34408_row4_col17, #T_34408_row10_col9 {
#   font-size: 4pt;
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_34408_row0_col10, #T_34408_row3_col13, #T_34408_row4_col7, #T_34408_row6_col16, #T_34408_row10_col19, #T_34408_row11_col18 {
#   font-size: 4pt;
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_34408_row0_col11, #T_34408_row0_col13, #T_34408_row2_col13, #T_34408_row3_col14, #T_34408_row7_col17, #T_34408_row11_col9, #T_34408_row13_col3, #T_34408_row14_col8 {
#   font-size: 4pt;
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_34408_row0_col14, #T_34408_row7_col16 {
#   font-size: 4pt;
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_34408_row0_col15, #T_34408_row1_col11, #T_34408_row2_col15, #T_34408_row4_col15 {
#   font-size: 4pt;
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_34408_row0_col16, #T_34408_row1_col6, #T_34408_row9_col5, #T_34408_row10_col7, #T_34408_row11_col5, #T_34408_row12_col4, #T_34408_row13_col7, #T_34408_row15_col3 {
#   font-size: 4pt;
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_34408_row0_col17, #T_34408_row0_col18, #T_34408_row1_col4, #T_34408_row2_col4, #T_34408_row3_col6, #T_34408_row4_col4, #T_34408_row5_col0, #T_34408_row5_col4, #T_34408_row5_col6, #T_34408_row6_col6, #T_34408_row8_col1, #T_34408_row8_col4, #T_34408_row8_col5, #T_34408_row9_col1, #T_34408_row10_col1, #T_34408_row12_col5, #T_34408_row12_col6, #T_34408_row16_col2, #T_34408_row16_col3 {
#   font-size: 4pt;
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_34408_row1_col3, #T_34408_row4_col0, #T_34408_row6_col1, #T_34408_row8_col6, #T_34408_row9_col4, #T_34408_row13_col5, #T_34408_row15_col2, #T_34408_row16_col7, #T_34408_row16_col8, #T_34408_row16_col9, #T_34408_row16_col10 {
#   font-size: 4pt;
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_34408_row1_col7, #T_34408_row1_col10, #T_34408_row5_col15, #T_34408_row9_col17, #T_34408_row11_col17 {
#   font-size: 4pt;
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_34408_row1_col8, #T_34408_row18_col18, #T_34408_row19_col17 {
#   font-size: 4pt;
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_34408_row1_col9 {
#   font-size: 4pt;
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_34408_row1_col14, #T_34408_row5_col7, #T_34408_row9_col19, #T_34408_row14_col9 {
#   font-size: 4pt;
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_34408_row1_col15, #T_34408_row8_col8, #T_34408_row14_col10 {
#   font-size: 4pt;
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_34408_row1_col17, #T_34408_row2_col6, #T_34408_row2_col18, #T_34408_row7_col7, #T_34408_row8_col7, #T_34408_row11_col6, #T_34408_row11_col7, #T_34408_row12_col7, #T_34408_row12_col8, #T_34408_row13_col6, #T_34408_row16_col5, #T_34408_row16_col6 {
#   font-size: 4pt;
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_34408_row2_col5, #T_34408_row3_col5, #T_34408_row4_col5, #T_34408_row4_col6, #T_34408_row6_col4, #T_34408_row7_col6, #T_34408_row11_col1, #T_34408_row12_col1, #T_34408_row13_col1, #T_34408_row14_col1, #T_34408_row15_col1, #T_34408_row17_col5, #T_34408_row17_col6, #T_34408_row17_col7, #T_34408_row17_col8 {
#   font-size: 4pt;
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_34408_row2_col7, #T_34408_row2_col16, #T_34408_row8_col17 {
#   font-size: 4pt;
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_34408_row2_col8, #T_34408_row8_col14, #T_34408_row17_col16 {
#   font-size: 4pt;
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_34408_row2_col9, #T_34408_row7_col11, #T_34408_row9_col11 {
#   font-size: 4pt;
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_34408_row2_col10 {
#   font-size: 4pt;
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_34408_row2_col12, #T_34408_row6_col18 {
#   font-size: 4pt;
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_34408_row3_col7, #T_34408_row3_col16, #T_34408_row13_col19 {
#   font-size: 4pt;
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_34408_row3_col8, #T_34408_row13_col14, #T_34408_row16_col17 {
#   font-size: 4pt;
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_34408_row3_col9 {
#   font-size: 4pt;
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_34408_row3_col10 {
#   font-size: 4pt;
#   background-color: #68be70;
#   color: #000000;
# }
# #T_34408_row3_col11, #T_34408_row19_col19 {
#   font-size: 4pt;
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_34408_row3_col18, #T_34408_row3_col19, #T_34408_row8_col19 {
#   font-size: 4pt;
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_34408_row4_col8, #T_34408_row4_col11, #T_34408_row14_col11 {
#   font-size: 4pt;
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_34408_row4_col9 {
#   font-size: 4pt;
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_34408_row4_col10 {
#   font-size: 4pt;
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_34408_row4_col12 {
#   font-size: 4pt;
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_34408_row4_col14 {
#   font-size: 4pt;
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_34408_row4_col18, #T_34408_row14_col18 {
#   font-size: 4pt;
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_34408_row4_col19, #T_34408_row6_col19 {
#   font-size: 4pt;
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_34408_row5_col8, #T_34408_row8_col12, #T_34408_row9_col12, #T_34408_row17_col17 {
#   font-size: 4pt;
#   background-color: #94d390;
#   color: #000000;
# }
# #T_3
# <style type="text/css">
# #T_0d4b5_row0_col0, #T_0d4b5_row1_col0, #T_0d4b5_row4_col0, #T_0d4b5_row6_col4, #T_0d4b5_row6_col5, #T_0d4b5_row8_col1, #T_0d4b5_row9_col1, #T_0d4b5_row12_col5, #T_0d4b5_row12_col6, #T_0d4b5_row16_col5, #T_0d4b5_row16_col6, #T_0d4b5_row16_col7, #T_0d4b5_row16_col8, #T_0d4b5_row16_col9 {
#   font-size: 4pt;
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0d4b5_row0_col1, #T_0d4b5_row0_col3, #T_0d4b5_row1_col1, #T_0d4b5_row2_col0, #T_0d4b5_row5_col4, #T_0d4b5_row6_col1, #T_0d4b5_row7_col1, #T_0d4b5_row8_col5, #T_0d4b5_row13_col5, #T_0d4b5_row13_col6, #T_0d4b5_row15_col2, #T_0d4b5_row15_col3, #T_0d4b5_row16_col10 {
#   font-size: 4pt;
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_0d4b5_row0_col2, #T_0d4b5_row0_col4, #T_0d4b5_row3_col0, #T_0d4b5_row4_col1, #T_0d4b5_row5_col1, #T_0d4b5_row5_col3, #T_0d4b5_row6_col3, #T_0d4b5_row6_col17, #T_0d4b5_row7_col3, #T_0d4b5_row9_col4, #T_0d4b5_row12_col7, #T_0d4b5_row12_col8, #T_0d4b5_row13_col7, #T_0d4b5_row15_col4 {
#   font-size: 4pt;
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_0d4b5_row0_col5, #T_0d4b5_row1_col4, #T_0d4b5_row4_col15, #T_0d4b5_row10_col6, #T_0d4b5_row10_col7, #T_0d4b5_row13_col9 {
#   font-size: 4pt;
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_0d4b5_row0_col6, #T_0d4b5_row11_col19 {
#   font-size: 4pt;
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_0d4b5_row0_col7, #T_0d4b5_row5_col15 {
#   font-size: 4pt;
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_0d4b5_row0_col8, #T_0d4b5_row5_col18 {
#   font-size: 4pt;
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_0d4b5_row0_col9, #T_0d4b5_row1_col6, #T_0d4b5_row6_col7, #T_0d4b5_row9_col16, #T_0d4b5_row10_col9 {
#   font-size: 4pt;
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_0d4b5_row0_col10, #T_0d4b5_row1_col5, #T_0d4b5_row3_col5, #T_0d4b5_row6_col18, #T_0d4b5_row12_col18 {
#   font-size: 4pt;
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_0d4b5_row0_col11, #T_0d4b5_row5_col17, #T_0d4b5_row8_col7, #T_0d4b5_row13_col3, #T_0d4b5_row14_col7, #T_0d4b5_row15_col10 {
#   font-size: 4pt;
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_0d4b5_row0_col12, #T_0d4b5_row2_col1, #T_0d4b5_row2_col14, #T_0d4b5_row3_col1, #T_0d4b5_row8_col3, #T_0d4b5_row12_col4, #T_0d4b5_row15_col5, #T_0d4b5_row15_col6 {
#   font-size: 4pt;
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0d4b5_row0_col13, #T_0d4b5_row3_col4, #T_0d4b5_row9_col6, #T_0d4b5_row9_col7, #T_0d4b5_row9_col19, #T_0d4b5_row14_col8 {
#   font-size: 4pt;
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_0d4b5_row0_col14, #T_0d4b5_row4_col19, #T_0d4b5_row18_col17 {
#   font-size: 4pt;
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_0d4b5_row0_col15, #T_0d4b5_row6_col12, #T_0d4b5_row9_col14, #T_0d4b5_row18_col16 {
#   font-size: 4pt;
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_0d4b5_row0_col16 {
#   font-size: 4pt;
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_0d4b5_row0_col17, #T_0d4b5_row5_col12, #T_0d4b5_row9_col13 {
#   font-size: 4pt;
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_0d4b5_row0_col18, #T_0d4b5_row14_col18 {
#   font-size: 4pt;
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_0d4b5_row0_col19, #T_0d4b5_row2_col19 {
#   font-size: 4pt;
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_0d4b5_row1_col2, #T_0d4b5_row1_col13, #T_0d4b5_row2_col2, #T_0d4b5_row3_col2, #T_0d4b5_row3_col14, #T_0d4b5_row3_col15, #T_0d4b5_row4_col2, #T_0d4b5_row4_col3, #T_0d4b5_row5_col2, #T_0d4b5_row5_col5, #T_0d4b5_row5_col16, #T_0d4b5_row9_col3, #T_0d4b5_row10_col3, #T_0d4b5_row10_col4, #T_0d4b5_row11_col4, #T_0d4b5_row11_col5, #T_0d4b5_row11_col8, #T_0d4b5_row13_col2, #T_0d4b5_row13_col4, #T_0d4b5_row13_col8, #T_0d4b5_row14_col2, #T_0d4b5_row14_col4, #T_0d4b5_row14_col5, #T_0d4b5_row15_col7 {
#   font-size: 4pt;
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_0d4b5_row1_col3, #T_0d4b5_row1_col12, #T_0d4b5_row2_col3, #T_0d4b5_row2_col13, #T_0d4b5_row3_col3, #T_0d4b5_row4_col4, #T_0d4b5_row4_col16, #T_0d4b5_row6_col2, #T_0d4b5_row7_col2, #T_0d4b5_row7_col6, #T_0d4b5_row7_col17, #T_0d4b5_row7_col18, #T_0d4b5_row8_col2, #T_0d4b5_row8_col6, #T_0d4b5_row8_col18, #T_0d4b5_row9_col2, #T_0d4b5_row9_col5, #T_0d4b5_row10_col2, #T_0d4b5_row10_col5, #T_0d4b5_row10_col8, #T_0d4b5_row11_col2, #T_0d4b5_row11_col3, #T_0d4b5_row11_col6, #T_0d4b5_row11_col7, #T_0d4b5_row12_col2, #T_0d4b5_row12_col3, #T_0d4b5_row12_col9, #T_0d4b5_row14_col3, #T_0d4b5_row14_col6, #T_0d4b5_row15_col8, #T_0d4b5_row15_col9 {
#   font-size: 4pt;
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0d4b5_row1_col7, #T_0d4b5_row2_col15, #T_0d4b5_row5_col14 {
#   font-size: 4pt;
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_0d4b5_row1_col8, #T_0d4b5_row10_col11, #T_0d4b5_row18_col19 {
#   font-size: 4pt;
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_0d4b5_row1_col9, #T_0d4b5_row6_col13, #T_0d4b5_row9_col9 {
#   font-size: 4pt;
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_0d4b5_row1_col10, #T_0d4b5_row3_col6 {
#   font-size: 4pt;
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_0d4b5_row1_col11, #T_0d4b5_row2_col4, #T_0d4b5_row3_col13, #T_0d4b5_row8_col19, #T_0d4b5_row9_col8 {
#   font-size: 4pt;
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_0d4b5_row1_col14, #T_0d4b5_row2_col5, #T_0d4b5_row9_col17, #T_0d4b5_row10_col17 {
#   font-size: 4pt;
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_0d4b5_row1_col15, #T_0d4b5_row2_col8 {
#   font-size: 4pt;
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_0d4b5_row1_col16, #T_0d4b5_row8_col9 {
#   font-size: 4pt;
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_0d4b5_row1_col17, #T_0d4b5_row8_col14, #T_0d4b5_row13_col16, #T_0d4b5_row14_col15 {
#   font-size: 4pt;
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_0d4b5_row1_col18 {
#   font-size: 4pt;
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_0d4b5_row1_col19, #T_0d4b5_row4_col12, #T_0d4b5_row10_col16, #T_0d4b5_row14_col19 {
#   font-size: 4pt;
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_0d4b5_row2_col6, #T_0d4b5_row4_col17, #T_0d4b5_row6_col15 {
#   font-size: 4pt;
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_0d4b5_row2_col7, #T_0d4b5_row13_col18, #T_0d4b5_row18_col11 {
#   font-size: 4pt;
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_0d4b5_row2_col9 {
#   font-size: 4pt;
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_0d4b5_row2_col10, #T_0d4b5_row7_col13, #T_0d4b5_row11_col16, #T_0d4b5_row18_col18 {
#   font-size: 4pt;
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_0d4b5_row2_col11 {
#   font-size: 4pt;
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_0d4b5_row2_col12, #T_0d4b5_row4_col14, #T_0d4b5_row6_col6, #T_0d4b5_row6_col16, #T_0d4b5_row11_col9 {
#   font-size: 4pt;
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_0d4b5_row2_col16, #T_0d4b5_row4_col8, #T_0d4b5_row4_col11, #T_0d4b5_row11_col15, #T_0d4b5_row13_col14, #T_0d4b5_row14_col16 {
#   font-size: 4pt;
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_0d4b5_row2_col17, #T_0d4b5_row5_col8, #T_0d4b5_row17_col16 {
#   font-size: 4pt;
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_0d4b5_row2_col18, #T_0d4b5_row16_col11, #T_0d4b5_row17_col11 {
#   font-size: 4pt;
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0d4b5_row3_col7 {
#   font-size: 4pt;
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_0d4b5_row3_col8 {
#   font-size: 4pt;
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_0d4b5_row3_col9 {
#   font-size: 4pt;
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_0d4b5_row3_col10, #T_0d4b5_row10_col14, #T_0d4b5_row16_col12 {
#   font-size: 4pt;
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_0d4b5_row3_col11 {
#   font-size: 4pt;
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_0d4b5_row3_col12, #T_0d4b5_row11_col17 {
#   font-size: 4pt;
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_0d4b5_row3_col16 {
#   font-size: 4pt;
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_0d4b5_row3_col17 {
#   font-size: 4pt;
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_0d4b5_row3_col1

# %%
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1]

print('Number of training examples: m_train = ' + str(m_train))
print('Number of testing examples: m_test = ' + str(m_test))
print ("Height/Width of each image: num_px = " + str(num_px))
print ("train_set_x shape: " + str(train_set_x_orig.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x shape: " + str(test_set_x_orig.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
# Out:
# Number of training examples: m_train = 209
# Number of testing examples: m_test = 50
# Height/Width of each image: num_px = 64
# train_set_x shape: torch.Size([209, 64, 64, 3])
# train_set_y shape: torch.Size([1, 209])
# test_set_x shape: torch.Size([50, 64, 64, 3])
# test_set_y shape: torch.Size([1, 50])

# %% [markdown]
# A Dataset in PyTorch is required to return a tuple of `(x,y)` when indexed. Python provides a `zip` function which, when combined with list, provides a simple way to get this functionality:

# %%
# Note: Understanding zip.
list1 = [1, 2, 3]
list2 = ['a', 'b', 'c']

zipped = zip(list1, list2)  # zip the two lists. Note zip is an iterator
zipped_list = list(zipped)  # convert the iterator to a list
print(zipped_list)
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
train_y = train_set_y.T
train_x = train_set_x_orig.view(-1, 3*num_px*num_px) / 255 # flatten and normalize
dset = list(zip(train_x, train_y))
x, y = dset[0] # get first sample
x.shape, y
# Out:
# (torch.Size([12288]), tensor([0]))

# %%
valid_y = test_set_y.T
valid_x = test_set_x_orig.view(-1, 3*num_px*num_px) / 255 # flatten and normalize
valid_dset = list(zip(valid_x, valid_y))
v_x, v_y = valid_dset[0] # get first sample
v_x.shape, v_y
# Out:
# (torch.Size([12288]), tensor([1]))

# %%
def init_params(size, std=1.0): return (torch.randn(size)*std).requires_grad_()

# %%
def loss_function(y_hat, y):
    loss = -y * torch.log(y_hat) - (1 - y) * torch.log(1 - y_hat)
    return loss

# %%
# propagate is similar calc_grad
def propagate_2(linear_layer, w, b, X, Y):
    m = X.shape[1]

    # FORWARD PROPAGATION (FROM X TO COST)
    # z = X@w.T + b  # linear function
    z = linear_layer(X)
    A = z.sigmoid() # compute activation
    loss = loss_function(A, Y)  # compute loss
    cost = 1 / m * torch.sum(loss)  # compute cost

    # BACKWARD PROPAGATION (TO FIND GRAD)
    # loss.backward() # backward must be computed on scalar (i.e. cost) not a vector (i.e. loss)
    cost.backward()

    return cost

# %%
def optimize_2(xb, yb, linear_layer, num_iterations=100, learning_rate=0.009, print_cost=False):
    w, b = linear_layer.parameters()
    costs = []

    for i in range(num_iterations):

        # propagate seems to be similar to train_epoch
        cost = propagate_2(linear_layer, w, b, xb, yb)

        # Note: The .data is a special attribute in pytorch where the gradient is not computed when used.
        w.data -= learning_rate * w.grad.data
        b.data -= learning_rate * b.grad.data
        w.grad.zero_()
        b.grad.zero_()

        # Record the costs
        if i % 100 == 0:
            costs.append(cost.item())  # Append the scalar value
        
            # Print the cost every 100 training iterations
            if print_cost:
                print ("Cost after iteration %i: %f" %(i, cost.item()))
    
    params = {"w": w, "b": b}

    return params, costs

# %%
def predict_2(linear_layer, w, b, X):
    m = X.shape[1]
    Y_prediction = torch.zeros((1, m))
    # z = w@X + b  # linear function
    z = linear_layer(X)
    A = z.sigmoid() # compute activation

    for i in range(A.shape[1]):
        if A[0, i] > 0.5:
            Y_prediction[0, i] = 1
        else:
            Y_prediction[0,i] = 0
    
    return Y_prediction

# %%
def model_2(dset, valid_dset, num_iterations=2000, learning_rate=0.5, print_cost=False):
    m = len(dset) # number of samples
    x, y = dset[0]
    dim = x.shape[0]
    linear_layer = nn.Linear(dim, 1)

    dl = DataLoader(dset, batch_size=m)
    for xb, yb in dl:
        params, costs = optimize_2(xb, yb, linear_layer, num_iterations, learning_rate, print_cost)

        w = params['w']
        b = params['b']
        # Y_prediction_test = predict(linear_layer, w, b, X_test)
        Y_prediction_train = predict_2(linear_layer, w, b, xb)

        # Print train/test Errors
        if print_cost:
            print("train accuracy: {} %".format(100 - torch.mean(np.abs(Y_prediction_train - yb)) * 100))
            # print("test accuracy: {} %".format(100 - torch.mean(np.abs(Y_prediction_test - Y_test)) * 100))
    

    d = {"costs": torch.tensor(costs),
        #  "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    # xb, yb = first(dl)
    # print(xb.shape, yb.shape)

    # # valid_dl = DataLoader(valid_dset, batch_size=valid_m)
    return d

# %%
lrm_2 = model_2(dset, valid_dset, num_iterations=2000, learning_rate=0.005, print_cost=True)
# Out:
# Cost after iteration 0: 0.011915
# Cost after iteration 100: 0.011052
# Cost after iteration 200: 0.010922
# Cost after iteration 300: 0.010803
# Cost after iteration 400: 0.010695
# Cost after iteration 500: 0.010595
# Cost after iteration 600: 0.010503
# Cost after iteration 700: 0.010417
# Cost after iteration 800: 0.010336
# Cost after iteration 900: 0.010259
# Cost after iteration 1000: 0.010187
# Cost after iteration 1100: 0.010118
# Cost after iteration 1200: 0.010053
# Cost after iteration 1300: 0.009990
# Cost after iteration 1400: 0.009930
# Cost after iteration 1500: 0.009872
# Cost after iteration 1600: 0.009816
# Cost after iteration 1700: 0.009761
# Cost after iteration 1800: 0.009709
# Cost after iteration 1900: 0.009658
# train accuracy: 65.55023956298828 %

# %% [markdown]
# ----

# %%
train_set_x_flatten = train_set_x_orig.reshape(m_train, -1).T
test_set_x_flatten = test_set_x_orig.reshape(m_test, -1).T

# Check that the first 10 pixels of the second image are in the correct place
assert torch.all(torch.eq(train_set_x_flatten[0:10, 1], torch.tensor([196, 192, 190, 193, 186, 182, 188, 179, 174, 213]))), "Wrong solution. Use (X.shape[0], -1).T."
assert torch.all(torch.eq(test_set_x_flatten[0:10, 1], torch.tensor([115, 110, 111, 137, 129, 129, 155, 146, 145, 159]))), "Wrong solution. Use (X.shape[0], -1).T."


print ("train_set_x_flatten shape: " + str(train_set_x_flatten.shape))
print ("train_set_y shape: " + str(train_set_y.shape))
print ("test_set_x_flatten shape: " + str(test_set_x_flatten.shape))
print ("test_set_y shape: " + str(test_set_y.shape))
print("\n")
# train_set_x_flatten = train_set_x_orig.reshape(m_train, -1)
# test_set_x_flatten = test_set_x_orig.reshape(m_test, -1)
# print ("train_set_x_flatten shape: " + str(train_set_x_flatten.shape))
# print ("train_set_y shape: " + str(train_set_y.shape))
# print ("test_set_x_flatten shape: " + str(test_set_x_flatten.shape))
# print ("test_set_y shape: " + str(test_set_y.shape))

# print("\n")
# train_set_y = train_set_y.reshape(1, -1).T
# test_set_y = test_set_y.reshape(1, -1).T
# print ("train_set_y shape: " + str(train_set_y.shape))
# print ("test_set_y shape: " + str(test_set_y.shape))
# Out:
# train_set_x_flatten shape: torch.Size([12288, 209])
# train_set_y shape: torch.Size([1, 209])
# test_set_x_flatten shape: torch.Size([12288, 50])
# test_set_y shape: torch.Size([1, 50])

# %% [markdown]
# Let's standardize our dataset.

# %%
train_set_x = train_set_x_flatten / 255.
test_set_x = test_set_x_flatten / 255.

# %% [markdown]
# # Model

# %%
def propagate(linear_layer, w, b, X, Y):
    m = X.shape[1]

    # FORWARD PROPAGATION (FROM X TO COST)
    z = w@X + b  # linear function
    # z = linear_layer(X)
    A = z.sigmoid() # compute activation
    loss = loss_function(A, Y)  # compute loss
    cost = 1 / m * torch.sum(loss)  # compute cost

    # BACKWARD PROPAGATION (TO FIND GRAD)
    # loss.backward() # backward must be computed on scalar (i.e. cost) not a vector (i.e. loss)
    cost.backward()

    # Get rid of these later and change to torch_dw and torch_db
    dw = w.grad
    db = b.grad

    return cost

# %%
def optimize(linear_layer, X, Y, num_iterations=100, learning_rate=0.009, print_cost=False):
    w, b = linear_layer.parameters()
    costs = []

    for i in range(num_iterations):
        cost = propagate(linear_layer, w, b, X, Y)

        # Note: The .data is a special attribute in pytorch where the gradient is not computed when used.
        w.data -= learning_rate * w.grad.data
        b.data -= learning_rate * b.grad.data
        w.grad.zero_()
        b.grad.zero_()

        # Record the costs
        if i % 100 == 0:
            costs.append(cost.item())  # Append the scalar value
        
            # Print the cost every 100 training iterations
            if print_cost:
                print ("Cost after iteration %i: %f" %(i, cost.item()))

    params = {"w": w, "b": b}

    return params, costs

# %%
def predict(linear_layer, w, b, X):
    m = X.shape[1]
    Y_prediction = torch.zeros((1, m))
    z = w@X + b  # linear function
    # z = linear_layer(X)
    A = z.sigmoid() # compute activation

    for i in range(A.shape[1]):
        if A[0, i] > 0.5:
            Y_prediction[0, i] = 1
        else:
            Y_prediction[0,i] = 0
    
    return Y_prediction

# %%
def model(X_train, Y_train, X_test, Y_test, num_iterations=2000, learning_rate=0.5, print_cost=False):
    dim = X_train.shape[0]
    m = X_train.shape[1]
    linear_layer = nn.Linear(dim, 1)
    params, costs = optimize(linear_layer, X_train, Y_train, num_iterations, learning_rate, print_cost)

    w = params['w']
    b = params['b']
    Y_prediction_test = predict(linear_layer, w, b, X_test)
    Y_prediction_train = predict(linear_layer, w, b, X_train)

    # Print train/test Errors
    if print_cost:
        print("train accuracy: {} %".format(100 - torch.mean(np.abs(Y_prediction_train - Y_train)) * 100))
        print("test accuracy: {} %".format(100 - torch.mean(np.abs(Y_prediction_test - Y_test)) * 100))
    
    d = {"costs": torch.tensor(costs),
         "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

# %%
logistic_regression_model = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations=2000, learning_rate=0.005, print_cost=True)
# Out:
# Cost after iteration 0: 0.760467
# Cost after iteration 100: 0.586323
# Cost after iteration 200: 0.468497
# Cost after iteration 300: 0.377249
# Cost after iteration 400: 0.332160
# Cost after iteration 500: 0.303866
# Cost after iteration 600: 0.280390
# Cost after iteration 700: 0.260485
# Cost after iteration 800: 0.243327
# Cost after iteration 900: 0.228344
# Cost after iteration 1000: 0.215119
# Cost after iteration 1100: 0.203345
# Cost after iteration 1200: 0.192783
# Cost after iteration 1300: 0.183248
# Cost after iteration 1400: 0.174592
# Cost after iteration 1500: 0.166697
# Cost after iteration 1600: 0.159464
# Cost after iteration 1700: 0.152813
# Cost after iteration 1800: 0.146676
# Cost after iteration 1900: 0.140996
# train accuracy: 99.04306030273438 %
# test accuracy: 70.0 %

# %%
# Plot learning curve (with costs)
costs = torch.squeeze(logistic_regression_model['costs'])
plt.plot(costs)
plt.ylabel('cost')
plt.xlabel('iterations (per hundreds)')
plt.title("Learning rate =" + str(logistic_regression_model["learning_rate"]))
plt.show()

# %%
index = 6
plt.imshow(test_set_x[:,index].reshape((num_px, num_px, 3)))
print ("y = " + str(test_set_y[0,index]) + ", you predicted that it is a \"" + str(int(logistic_regression_model['Y_prediction_test'][0,index])) +  "\" picture.")
# Out:
# y = tensor(1), you predicted that it is a "0" picture.

# %%
learning_rates = [0.01, 0.001, 0.0001]
models = {}

for lr in learning_rates:
    print ("Training a model with learning rate: " + str(lr))
    models[str(lr)] = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations=1500, learning_rate=lr, print_cost=False)
    print ('\n' + "-------------------------------------------------------" + '\n')

for lr in learning_rates:
    plt.plot(np.squeeze(models[str(lr)]["costs"]), label=str(models[str(lr)]["learning_rate"]))

plt.ylabel('cost')
plt.xlabel('iterations (hundreds)')

legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# Training a model with learning rate: 0.01
# -------------------------------------------------------
#
# Training a model with learning rate: 0.001
#
# -------------------------------------------------------
#
# Training a model with learning rate: 0.0001
#
# -------------------------------------------------------
